# %%
import pandas as pd

# %%
movies = pd.read_csv('data/movies25.csv')
ratings = pd.read_csv('data/ratings25.csv')
links = pd.read_csv('data/links25.csv')

movies.shape, links.shape
# Out:
# ((62423, 3), (62423, 3))

# %%
# merge movies and links by movieId
movies_links = pd.merge(movies, links, on='movieId')
movies_links.shape
# Out:
# (62423, 5)

# %%
movies_links.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  imdbId   tmdbId
# 0  Adventure|Animation|Children|Comedy|Fantasy  114709    862.0
# 1                   Adventure|Children|Fantasy  113497   8844.0
# 2                               Comedy|Romance  113228  15602.0
# 3                         Comedy|Drama|Romance  114885  31357.0
# 4                                       Comedy  113041  11862.0

# %%
movies_links[['title', 'year']] = movies_links['title'].str.extract(r'^(.*) \((\d{4})\)$')

# %%
movies_links
# Out:
#        movieId                        title  \
# 0            1                    Toy Story
# 1            2                      Jumanji
# 2            3             Grumpier Old Men
# 3            4            Waiting to Exhale
# 4            5  Father of the Bride Part II
# ...        ...                          ...
# 62418   209157                           We
# 62419   209159           Window of the Soul
# 62420   209163                    Bad Poems
# 62421   209169                 A Girl Thing
# 62422   209171      Women of Devil's Island
#
#                                             genres   imdbId    tmdbId  year
# 0      Adventure|Animation|Children|Comedy|Fantasy   114709     862.0  1995
# 1                       Adventure|Children|Fantasy   113497    8844.0  1995
# 2                                   Comedy|Romance   113228   15602.0  1995
# 3                             Comedy|Drama|Romance   114885   31357.0  1995
# ...

# %%
movies_links.isnull().sum()
# Out:
# movieId      0
# title      572
# genres       0
# imdbId       0
# tmdbId     107
# year       572
# dtype: int64

# %%
# show rows where null values
movies_links[movies_links['year'].isnull()]
# Out:
#        movieId title                         genres    imdbId    tmdbId year
# 7733      8359   NaN                          Drama     83090  258236.0  NaN
# 8463     25936   NaN                          Drama     40142   43452.0  NaN
# 8602     26137   NaN               Action|Drama|War     59263   16850.0  NaN
# 8910     26628   NaN  Crime|Horror|Mystery|Thriller     95389   41959.0  NaN
# 9006     26815   NaN                   Comedy|Drama    106685  251732.0  NaN
# ...        ...   ...                            ...       ...       ...  ...
# 62071   207714   NaN             (no genres listed)  11101550  640427.0  NaN
# 62104   207884   NaN             (no genres listed)   4602718  528815.0  NaN
# 62285   208597   NaN                    Documentary   3736766  636391.0  NaN
# 62326   208763   NaN             (no genres listed)     98693  352556.0  NaN
# 62380   208973   NaN             (no genres listed)    215759  514317.0  NaN
#
# [572 rows x 6 columns]

# %%
# get the list of ids of the rows where year is null
null_ids = movies_links[movies_links['year'].isnull()].index

# %%
ratings = ratings[~ratings['movieId'].isin(null_ids)]
movies_links = movies_links[~movies_links['year'].isnull()]

# %%
movies_links.to_csv('data/movies_complete.csv', index=False)
ratings.to_csv('data/ratings_complete.csv', index=False)

# %%
# from ratings, get the list of the unique userId and save it in a dataframe
users = pd.DataFrame(ratings['userId'].unique(), columns=['userId'])
users.head()
# Out:
#    userId
# 0       1
# 1       2
# 2       3
# 3       4
# 4       5

# %%
users.to_csv('data/users.csv', index=False)

# %%
movies = pd.read_csv('data/movies_complete.csv')
ratings = pd.read_csv('data/ratings25.csv')
metadata = pd.read_csv('data/movies_metadata.csv')

movies.shape, ratings.shape, metadata.shape
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_25560\2406630982.py:3: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   metadata = pd.read_csv('data/movies_metadata.csv')
# ((40968, 10), (25000095, 4), (45466, 24))

# %%
# in movies, tmdbId convert to int
movies['tmdbId'] = movies['tmdbId'].fillna(0).astype(int)
# remove rows where tmdbId is 0
movies = movies[movies['tmdbId'] != 0]
movies.head()
# Out:
#    movieId                        title  \
# 0        1                    Toy Story
# 1        2                      Jumanji
# 2        3             Grumpier Old Men
# 3        4            Waiting to Exhale
# 4        5  Father of the Bride Part II
#
#                                         genres  imdbId  tmdbId  year     id  \
# 0  Adventure|Animation|Children|Comedy|Fantasy  114709     862  1995    862
# 1                   Adventure|Children|Fantasy  113497    8844  1995   8844
# 2                               Comedy|Romance  113228   15602  1995  15602
# 3                         Comedy|Drama|Romance  114885   31357  1995  31357
# 4                                       Comedy  113041   11862  1995  11862
#
#                                             overview  vote_average  \
# 0  Led by Woody, Andy's toys live happily in his ...           7.7
# 1  When siblings Judy and Peter discover an encha...           6.9
# ...

# %%
metadata.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
metadata = metadata[['id', 'overview', 'vote_average', 'poster_path']]

# %%
metadata.isnull().sum()
# Out:
# id                0
# overview        954
# vote_average      6
# poster_path     386
# dtype: int64

# %%
metadata.dropna(inplace=True)

# %%
# metadata id as int
metadata['id'] = metadata['id'].astype(int)

# %%
# keep rows in movies where tmdbId is in metadata id and add overview and vote_average
movies = pd.merge(movies, metadata, left_on='tmdbId', right_on='id')
movies.shape
# Out:
# (41082, 14)

# %%
movies.head()
# Out:
#    movieId                        title  \
# 0        1                    Toy Story
# 1        2                      Jumanji
# 2        3             Grumpier Old Men
# 3        4            Waiting to Exhale
# 4        5  Father of the Bride Part II
#
#                                         genres  imdbId  tmdbId  year   id_x  \
# 0  Adventure|Animation|Children|Comedy|Fantasy  114709     862  1995    862
# 1                   Adventure|Children|Fantasy  113497    8844  1995   8844
# 2                               Comedy|Romance  113228   15602  1995  15602
# 3                         Comedy|Drama|Romance  114885   31357  1995  31357
# 4                                       Comedy  113041   11862  1995  11862
#
#                                           overview_x  vote_average_x  \
# 0  Led by Woody, Andy's toys live happily in his ...             7.7
# 1  When siblings Judy and Peter discover an encha...             6.9
# ...

# %%
movies.drop(columns=['id'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 movies.drop(columns=['id'], inplace=True)
#
# File c:\Users\andre\miniconda3\envs\concurrent-env\lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
# keep rows in ratings where movieId is in movies movieId
ratings = ratings[ratings['movieId'].isin(movies['movieId'])]
ratings.shape
# Out:
# (24718797, 4)

# %%
movies.head()
# Out:
#    movieId                        title  \
# 0        1                    Toy Story
# 1        2                      Jumanji
# 2        3             Grumpier Old Men
# 3        4            Waiting to Exhale
# 4        5  Father of the Bride Part II
#
#                                         genres  imdbId  tmdbId  year     id  \
# 0  Adventure|Animation|Children|Comedy|Fantasy  114709     862  1995    862
# 1                   Adventure|Children|Fantasy  113497    8844  1995   8844
# 2                               Comedy|Romance  113228   15602  1995  15602
# 3                         Comedy|Drama|Romance  114885   31357  1995  31357
# 4                                       Comedy  113041   11862  1995  11862
#
#                                             overview  vote_average  \
# 0  Led by Woody, Andy's toys live happily in his ...           7.7
# 1  When siblings Judy and Peter discover an encha...           6.9
# ...

# %%
movies.to_csv('data/movies_complete.csv', index=False)

# %%
ratings.to_csv('data/ratings_complete.csv', index=False)
